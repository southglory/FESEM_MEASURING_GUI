# %%
#9_9_2_BH이전에는 한 파일의 값을 불러오기 함. 이후에는 room 주소, room 번호를 부여함.
#9_9_3_BH버전에서는 [cases, [specimen names, specimens],[,],[,]...] 의 형태로 리스트화.
#9_9_5_BH버전에서는 xlwing macro 적용
import os
import tempfile
import subprocess
from parse import *
import xlwings as xw
from xlwings.constants import AutoFillType
from tqdm import tqdm_notebook
import time


# file = r"C:\Users\Hojin\Desktop\부식\전수조사 모음\전수조사 정리\Surfactant(X)_\30ml_\NT_\LiOH(0.06)_\INHIBIT(509)_\TEMP(200)_\HOUR(2500)_\s(9_13)\s(9_13)_xlsx_Pitdepth_data\s(9_13)\s(9_13)_xlsx_Pitdepth_data\s(9_13)pit_depth_result.xlsx"
# dir,filename = os.path.split(file)
# print("1 ",dir, "에 있는 ", filename)
# os.chdir(dir)
# folder = os.getcwd()
# fo1 =os.path.basename(dir)
# fo2=os.path.basename(fo1)
# print ('Current folder : %s' % folder)
# print( 'specimen: %s' % fo2)
# rn=parse("s({}_{})pit_depth_result.xlsx",filename)
#                         #print("8?=",rn.fixed[0],"22?=?",rn.fixed[1])
                      
# rn1=rn.fixed[0]+"0"+rn.fixed[1]
# print(rn1)
# if os.path.isfile(dir + os.sep+"s(9_13)pit_depth_result.xlsx"):
#     wb = xw.Book(dir + os.sep+ "s(9_13)pit_depth_result.xlsx")
# else:
#     wb = xw.Book()
    
# sht1 = wb.sheets[0]
# #엑셀 그림자에 데이터 저장.
# exshadow0 = []
# exshadow1 = []
# exshadow2 = []
# rownum = sht1.range('A2').end('down').last_cell.row
# print('rownum',rownum)
# for i in range(rownum-2):
#     print(sht1.range('A'+str(i+3)).value,sht1.range('B'+str(i+3)).value,sht1.range('C'+str(i+3)).value)
#     exshadow0.append(sht1.range('A'+str(i+3)).value)
#     exshadow0.append(sht1.range('B'+str(i+3)).value)
#     exshadow0.append(sht1.range('C'+str(i+3)).value)

# print(len(exshadow))

dir = "C:/Users/Hojin/Desktop/부식/전수조사 모음/전수조사 정리"
os.chdir(dir)
folder = os.getcwd()
print ('Current folder : %s' % folder)
search = '.xlsx'


cases=[]
specimen_n=[]
specimen=[]

for path, dirs, files in os.walk(folder):
    #print('\nFolder: ', path)
    if files:
        for filename in files:
            if search in os.path.join(path, filename):

                if "pit_depth_result" in os.path.join(path, filename):
                    #print ("filename: ", filename)
                    
 #                   print("path:",path)
                    base2, basen= os.path.split(path)
                    base1,base2n=os.path.split(base2)
                    print("cases:",base1)
                    
#                     wb2 = xw.Book(os.path.join(path, filename))
#                     sht2=wb2.sheets[0]

#                     wb2.save(os.path.join(path, filename))
#                     #wait()
#                     wb2.close()

                    rn=parse("s({}_{})pit_depth_result.xlsx",filename)
                    #print("8?=",rn.fixed[0],"22?=?",rn.fixed[1])

                    rn1=rn.fixed[0]+"0"+rn.fixed[1]
                    #print (' Files: ',rn1,  os.path.join(path, filename))
                    print ('specimen_n: ',rn1)
                    
                    
                    cases.append(base1)
                    specimen_n.append(rn1)
                    specimen.append(os.path.join(path, filename))
                    #print( os.path.splitext(filename)[1])
                        
print("case개수: ",len(cases)," specimen개수: ",len(specimen_n))
remove_dup=list(set(cases))
print(len(remove_dup))
print(remove_dup[0],"\n",remove_dup[1])
asd=[]
n=0
for search in remove_dup:
    asd.append([search])
    for i in range(len(cases)):#0,1,2,...
        if search == cases[i]:
            asd[n].append([specimen_n[i],specimen[i]])
    n+=1
print(len(asd))#asd꼴은([cases,[specimen_n,specimen]], ...)
print(len(asd[0]), ",",len(asd[10]))
print(asd[0][0])
"""
trash, case_n= os.path.split(asd[0][0])
print(case_n)
rn=parse("HOUR({})_",case_n)
rn1="s00"+rn.fixed[0]+"H"
print(rn1)
"""
#-----------------------------------------이후는 9_9_4_BH --------------------
ttimes=0
total = tqdm_notebook(range(len(asd)))
for k in total: #0,1,2,...
    
    
    """
    if os.path.isfile(asd[k][0]):
        wb = xw.Book(asd[k][0]+os.sep+"histogram.xlsx")
    else:
        wb = xw.Book()
        wb.save(asd[k][0]+os.sep+"histogram.xlsx")
    sht0 = wb.sheets[0]
    """
    #데이터 파일 열고 데이터 추출 wb1------------
    columnA = []
    columnB = []
    columnC = []
    for j in range(len(asd[k])-1):#0,1,2,...
        
        if os.path.isfile(asd[k][j+1][1]):#1,2,3,...
            wb1 = xw.Book(asd[k][j+1][1])
        else:
            #wb1 = xw.Book()
            pass
        sht1 = wb1.sheets[0]

        #엑셀 그림자에 데이터 저장.

        rownum = sht1.range('A2').end('down').last_cell.row
        print('rownum',rownum)
        for i in range(rownum-2):
            print(sht1.range('A'+str(i+3)).value,sht1.range('B'+str(i+3)).value,sht1.range('C'+str(i+3)).value)
            columnA.append(sht1.range('A'+str(i+3)).value)
            columnB.append(sht1.range('B'+str(i+3)).value)
            columnC.append(sht1.range('C'+str(i+3)).value)
        
        
        wb1.close()
        
    #------------------------------------------------
    print(columnA)
    
    #매크로엑셀 파일 열기 wb------------------------
    wb = xw.Book(r'c:\\Users\\Hojin\\Desktop\\부식\\전수조사 모음\\전수조사 정리\\히스토그램_w_py_rev.xlsm')
    sht0 = wb.sheets[0]
    
    #-----case name 파싱 for 입력
    trash, case_n= os.path.split(asd[0][0])
    print(case_n)
    rn=parse("HOUR({})_",case_n)
    rn1="s00"+rn.fixed[0]+"H"
    print(rn1)
    
    sht0.range('A1').value=[rn1]
    for j in range(len(columnA)):#0,1,2...
        sht0.range('A'+str(j+3)).value=columnA[j]
        sht0.range('B'+str(j+3)).value=columnB[j]
        sht0.range('C'+str(j+3)).value=columnC[j]
    
    #-----specimen name 파싱 for histogram : rn_histo2
    #------specimen name 파싱 for 저장이름 : speci_n
    rn_histo1=""
    rn_histo2=[]
    speci_n=""
    for j in range(len(asd[k])-1):#0,1,2,...
        print(asd[k][j+1][0])
        rn_histo=asd[k][j+1][0]
        print(rn_histo)
        rn_histo1="s"+rn_histo[0:1]+"_"+rn_histo[2:4]
        print(rn_histo1)
        rn_histo2.append(rn_histo1)
        print(rn_histo2)
        speci_n+= asd[k][j+1][0]+"_"
    
    #--------------빈 값 제거--------
    cC=[]
    rownum = sht0.range('A2').end('down').last_cell.row
    print('rownum',rownum)
    for i in range(rownum-2):
        print(sht0.range('C'+str(i+3)).value)
        cC.append(sht0.range('C'+str(i+3)).value)
        if sht0.range('C'+str(i+3)).value ==None:
            sht0.range('A'+str(i+3)+":C"+str(i+3)).api.Delete()
            
            
    #----------------매크로------------
    ExcelMacro = wb.macro("Naming_w_py")
    ExcelMacro()
    time.sleep(1)
    #---------rn_histo2 엑셀에 입력------------
    rns=""
    text=""
    print("rn_histo2= ",rn_histo2)
    if len(rn_histo2)==0:
        sht0.range('B1').value="data 부족"
    if len(rn_histo2)>0:
        rns=sht0.range('D3').value
        text="=SUMPRODUCT(("+rns+">G3)*("+rns+"<=G4))"
        sht0.range('H4').value=text
        sht0.range('H4').api.AutoFill(sht0.range("H4:H32").api,
                                   AutoFillType.xlFillDefault)
    
        rns=sht0.range('D4').value
        text="=SUMPRODUCT(("+rns+">Q3)*("+rns+"<=Q4))"
        sht0.range('R4').value=text
        sht0.range('R4').api.AutoFill(sht0.range("R4:R32").api,
                                   AutoFillType.xlFillDefault)
        #-----
    if len(rn_histo2)>1:
        rns=sht0.range('D5').value
        text="=SUMPRODUCT(("+rns+">G3)*("+rns+"<=G4))"
        sht0.range('H41').value=text
        sht0.range('H41').api.AutoFill(sht0.range("H41:H69").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>2:
        rns=sht0.range('D6').value
        text="=SUMPRODUCT(("+rns+">Q3)*("+rns+"<=Q4))"
        sht0.range('R41').value=text
        sht0.range('R41').api.AutoFill(sht0.range("R41:R69").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>3:
        #-----
        rns=sht0.range('D7').value
        text="=SUMPRODUCT(("+rns+">G3)*("+rns+"<=G4))"
        sht0.range('H75').value=text
        sht0.range('H75').api.AutoFill(sht0.range("H75:H103").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>4:
        rns=sht0.range('D8').value
        text="=SUMPRODUCT(("+rns+">Q3)*("+rns+"<=Q4))"
        sht0.range('R75').value=text
        sht0.range('R75').api.AutoFill(sht0.range("R75:R103").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>5:
        #-----
        rns=sht0.range('D9').value
        text="=SUMPRODUCT(("+rns+">G3)*("+rns+"<=G4))"
        sht0.range('H111').value=text
        sht0.range('H111').api.AutoFill(sht0.range("H111:H139").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>6:
        rns=sht0.range('D10').value
        text="=SUMPRODUCT(("+rns+">Q3)*("+rns+"<=Q4))"
        sht0.range('R111').value=text
        sht0.range('R111').api.AutoFill(sht0.range("R111:R139").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>7:
        #-----
        rns=sht0.range('D11').value
        text="=SUMPRODUCT(("+rns+">G3)*("+rns+"<=G4))"
        sht0.range('H145').value=text
        sht0.range('H145').api.AutoFill(sht0.range("H145:H173").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>8:
        rns=sht0.range('D12').value
        text="=SUMPRODUCT(("+rns+">Q3)*("+rns+"<=Q4))"
        sht0.range('R145').value=text
        sht0.range('R145').api.AutoFill(sht0.range("R145:R173").api,
                                   AutoFillType.xlFillDefault)
        #-----
    if len(rn_histo2)>9:
        #-----
        rns=sht0.range('D13').value
        text="=SUMPRODUCT(("+rns+">G3)*("+rns+"<=G4))"
        sht0.range('H178').value=text
        sht0.range('H178').api.AutoFill(sht0.range("H178:H206").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>10:
        rns=sht0.range('D14').value
        text="=SUMPRODUCT(("+rns+">Q3)*("+rns+"<=Q4))"
        sht0.range('R178').value=text
        sht0.range('R178').api.AutoFill(sht0.range("R178:R206").api,
                                   AutoFillType.xlFillDefault)
    if len(rn_histo2)>11:
        rns=sht0.range('D15').value
        sht0.range('B1').value="histogram 부족"
        wb.save(asd[k][0]+os.sep+speci_n+"histogram.xlsm")
        #-----
    
    time.sleep(1)
    
    
    wb.save(asd[k][0]+os.sep+speci_n+"histogram.xlsm")
    wb.close()
    
    ttimes+=1
    if ttimes/3==1:
        wait=input("Press Enter to Continue.")
        ttimes=0
    #--------------------------------------------------

"""
print(len(asd[0]))
for j in range(len(asd[0])-1):
    print(j+1)
    print(asd[0][j+1][1])
"""

# %%
"""
a= [[1,2],[]]
a.append([3])
a[0].append(7)

print(a[0][0])
b=[]
b.append([1])
b.append([2])
b.append(2)
print(b)
ggg="9123"
rn=parse("{}{}{}{}",ggg)
print(rn[3])
po="s"+"d"
print(po)
"""
# Out:
# 1
# [[1], [2], 2]
# 3
# sd

# %%
"""
dir = "C:/Users/Hojin/Desktop/부식/전수조사 모음/전수조사 정리"

print(dir + os.sep+ "file.xlsx")
"""
# Out:
# C:/Users/Hojin/Desktop/부식/전수조사 모음/전수조사 정리\file.xlsx
# ['5-10 down_15kV PC6 WD10_100.bmp', '5-10 down_15kV PC6 WD10_102.bmp', '5-10 down_15kV PC6 WD10_103.bmp', '5-10 down_15kV PC6 WD10_91.bmp', '5-10 down_15kV PC6 WD10_92.bmp', '5-10 down_15kV PC6 WD10_96.bmp', '5-10 down_15kV PC6 WD10_97.bmp', '5-10 down_15kV PC6 WD10_98.bmp', '5-10 up_15kV PC6 WD10_81.bmp', '5-10 up_15kV PC6 WD10_83.bmp', '5-10 up_15kV PC6 WD10_85.bmp', '5-10 up_15kV PC6 WD10_88.bmp', '5-14 down_15kV PC6 WD10_81.bmp', '5-14 down_15kV PC6 WD10_82.bmp', '5-14 down_15kV PC6 WD10_83.bmp', '5-14 down_15kV PC6 WD10_84.bmp', '5-14 down_15kV PC6 WD10_85.bmp', '5-14 down_15kV PC6 WD10_86.bmp', '5-14 down_15kV PC6 WD10_87.bmp', '5-14 down_15kV PC6 WD10_88.bmp', '5-14 down_15kV PC6 WD10_89.bmp', '5-14 down_15kV PC6 WD10_90.bmp', '5-14 down_15kV PC6 WD10_92.bmp', '5-14 up_15kV PC6 WD10_77.bmp']

# %%
"""
zzz="d"
zzz+="b"+"c"
print(zzz)
"""
# Out:
# dbc
